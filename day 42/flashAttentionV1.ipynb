# %%
# !nvidia-smi
# Out:
# Sun Jul 12 14:44:11 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   36C    P8             10W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %%
# !nvcc --version
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2025 NVIDIA Corporation
# Built on Fri_Feb_21_20:23:50_PST_2025
# Cuda compilation tools, release 12.8, V12.8.93
# Build cuda_12.8.r12.8/compiler.35583870_0

# %%
# !pip install nvcc4jupyter
# %load_ext nvcc4jupyter
# Out:
# Collecting nvcc4jupyter
#   Downloading nvcc4jupyter-1.2.1-py3-none-any.whl.metadata (5.1 kB)
# Downloading nvcc4jupyter-1.2.1-py3-none-any.whl (10 kB)
# Installing collected packages: nvcc4jupyter
# Successfully installed nvcc4jupyter-1.2.1
# Detected platform "Colab". Running its setup...
# Source files will be saved in "/tmp/tmp3g89o7gp".

# %%
import torch
from torch.utils.cpp_extension import load_inline

cuda_source = r"""
#include <torch/extension.h>
#include <cuda.h>
#include <cuda_runtime.h>
#include <float.h>

#define BLOCK_Q 32
#define BLOCK_K 32
__global__ void flash_atten_fwd_kernel(
    const float* __restrict__ Q,
    const float* __restrict__ K,
    const float* __restrict__ V,
    float* __restrict__ O,
    const int N, 
    const int d,
    const float scale
) {
    extern __shared__ float shared_mem[];
    float* Kt = shared_mem;
    float* Vt = shared_mem + BLOCK_K * d;

    const int q_block_start = blockIdx.x * BLOCK_Q;
    const int tid = threadIdx.x;
    const int q_row = q_block_start + tid; 

    float row_max = -FLT_MAX;
    float row_sum = 0.0f;

    float acc[128];
    for (int i = 0; i < 128; i++){
        acc[i] = 0.0f;
    }

    float q_req[128];
    if (q_row < N) {
        for (int i = 0; i < d; i++) {
            q_req[i] = Q[q_row * d + i];
        }
    }

    for (int k_block_start = 0; k_block_start < N; k_block_start += BLOCK_K) {
        int k_rows = min(BLOCK_K, N - k_block_start);

        for (int r = tid; r < k_rows; r+= BLOCK_Q) {
            for (int i = 0; i < d; i++) {
                Kt[r * d + i] = K[(k_block_start + r) * d + i];
                Vt[r * d + i] = V[(k_block_start + r) * d + i];
            }
        } 
        __syncthreads();

        if (q_row < N) {
            float scores[BLOCK_K];
            float block_MAX = -FLT_MAX;
            for (int i = 0; i < k_rows; i++){
                float s = 0.0f;
                for (int j = 0; j < d; j++) {
                    s += q_req[j] * Kt[i * d + j];
                }
                s *= scale;
                scores[i] = s;
                block_MAX = fmaxf(block_MAX, s);
            }
            
            float new_max = fmaxf(row_max, block_MAX);
            float correction = expf(row_max - new_max);

            row_sum *= correction;

            for(int i = 0; i < d; i++){
                acc[i] *= correction;
            }

            for (int i = 0; i < k_rows; i++){
                float p = expf(scores[i] - new_max);
                row_sum += p;
                for (int j = 0; j < d; j++){
                    acc[j] += p * Vt[i * d + j];
                }
            }
            row_max = new_max;
        }
    __syncthreads();
    }

    if (q_row < N) {
        for (int i = 0; i < d; i++) {
            O[q_row * d + i] = acc[i] / row_sum;
        }
    }
}

torch::Tensor flash_attn_forward(torch::Tensor Q, torch::Tensor K, torch::Tensor V) {
    const int N = Q.size(0);
    const int d = Q.size(1);
    const float scale = 1.0f / sqrtf((float)d);

    auto O = torch::empty({N, d}, Q.options());

    const int num_blocks = (N + BLOCK_Q - 1) / BLOCK_Q;
    const int threads_per_block = BLOCK_Q;
    const size_t shared_bytes = 2 * BLOCK_K * d * sizeof(float);

    flash_atten_fwd_kernel<<<num_blocks, threads_per_block, shared_bytes>>>(
        Q.data_ptr<float>(), K.data_ptr<float>(), V.data_ptr<float>(),
        O.data_ptr<float>(), N, d, scale
    );

    return O;
}
"""

# %%
cpp_source = "torch::Tensor flash_attn_forward(torch::Tensor Q, torch::Tensor K, torch::Tensor V);"

# %%
flash_attn_cuda = load_inline(
    name="flash_attn_cuda",
    cpp_sources=cpp_source,
    cuda_sources=cuda_source,
    functions=["flash_attn_forward"],
    verbose=True,
)

# %%
def naive_attention(Q, K, V):
    d = Q.shape[-1]
    scores = Q @ K.transpose(-2, -1) / (d ** 0.5)
    probs = torch.softmax(scores, dim=-1)
    return probs @ V

# %%
torch.manual_seed(0)
device = "cuda"

N, d = 300, 64
Q = torch.randn(N, d, device=device, dtype=torch.float32)
K = torch.randn(N, d, device=device, dtype=torch.float32)
V = torch.randn(N, d, device=device, dtype=torch.float32)

out_naive = naive_attention(Q, K, V)
out_cuda = flash_attn_cuda.flash_attn_forward(Q, K, V)

max_abs_diff = (out_naive - out_cuda).abs().max().item()
print(f"max abs difference vs naive reference: {max_abs_diff:.3e}")
print("match:", torch.allclose(out_naive, out_cuda, atol=1e-3))
# Out:
# max abs difference vs naive reference: 3.576e-07
# match: True
